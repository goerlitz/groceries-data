# %% [markdown]
# # OpenFoodFacts - Analysis of Packaging Data
#
# __Goal__: Investigate what kind of packaging information is included in the product data and if it is ready to use for display in an app.
#
# <div class="alert alert-block alert-info">
#   <b>This notebook focuses on the top 1,000 German products in Open Food Facts that are marked to have complete packaging information.</b>
# </div>
#
# __To be analyzed:__
#   - the stored packaging information, i.e. packaging containers, coverings, and material.
#   - the completeness and consistency of packaging data.
#   - statistics about most frequent type of packaging and materials.
#
# __Summary (TL;TR)__
#   - only a fraction (~0.9%) of German products are marked as having complete packaging data.
#   - those packaging details are still messy. For instance, some products
#     - don't have any packaging data.
#     - don't have a product name.
#     - are missing the "shape" or "material" information in the packaging details.
#     - are not properly annotated with the english taxonomy terms for "shape" and "material" but use other languages.
#     - have generic "shape" annotations: `en:packaging`, `en:grouping-package`, `en:unknown`.
#     - use annotations inconsistently, e.g. frozen pizza with "shape" `en:pizza-box` and `en:bag`|`en:wrapper`|`en:film`.
#     - have very specific material annotations, like `xx:80-c-pap`, that are less suitable for display to average customers.
#     - have non consolidated annotations, like `en:tetra-brik-aseptic`, `en:tetra-pak`, `en:tetra-brik`.
#
# __-> Given the number of discovered issues the overall data quality is questionable. Even if some products have no obvious data quality issues, it remains unclear if the packaging data is correct and complete.__

# %%
import pandas as pd
from urllib.request import urlopen, urlretrieve
from urllib.parse import urlencode
from pathlib import Path
import json

# %% [markdown]
# ## Download Data from OpenFoodFacts API
#
# ___Only fetch the top 1,000 German products with complete packaging information!___

# %%
API_URL = "https://de.openfoodfacts.org/api/v2/search?"

PARAMS = {
    "page_size": 1000,
    "misc_tags": "packagings-complete",
    "fields": "code,brands,product_name,packagings,packagings_complete,packaging_tags,unique_scans_n,image_small_url"
}

DATA_FILE = "../data/off_de_complete_packagings_top1000.json"

# skip download if data has been downloaded before
if not Path(DATA_FILE).exists():
    urlretrieve(API_URL + urlencode(PARAMS), DATA_FILE)

# %% [markdown]
# # Exploratory Data Analysis
#
# ## Data Preparation

# %%
# load json file
with open(DATA_FILE) as f:
    data = json.load(f)

# create data frame from product information
prod_df = (pd.DataFrame(data['products'])
            .drop(['packagings_complete', 'packaging_tags'], axis=1)
            .set_index('code')
          )

computations = {
    # count number of packaging items
    "pack_count": lambda items: len(items),

    # extract packaging shapes
    "pack_shapes": lambda items: [i['shape'] if ('shape' in i) else None for i in items],

    # extract packaging materials
    "pack_materials": lambda items: [i['material'] if ('material' in i) else None for i in items]
}

for key, fn in computations.items():
    prod_df[key] = prod_df.packagings.map(fn)

display(prod_df)
# Out:
#                     brands                                    image_small_url  \
# code
# 3274080005003   Cristaline  https://images.openfoodfacts.org/images/produc...
# 3017620422003      Ferrero  https://images.openfoodfacts.org/images/produc...
# 7622210449283  Lu,Mondelez  https://images.openfoodfacts.org/images/produc...
# 5449000214911    Coca cola  https://images.openfoodfacts.org/images/produc...
# 3017620425035      Ferrero  https://images.openfoodfacts.org/images/produc...
# ...                    ...                                                ...
# 8690565330289        Pinar  https://images.openfoodfacts.org/images/produc...
# 4021234101109    Barnhouse  https://images.openfoodfacts.org/images/produc...
# 4104420141827     Alnatura  https://images.openfoodfacts.org/images/produc...
# 42372394          Patronus  https://images.openfoodfacts.org/images/produc...
# 9002055108817       Sorger  https://images.openfoodfacts.org/images/produc...
#
#                                                       packagings  \
# code
# 3274080005003  [{'material': 'en:pet-1-polyethylene-terephtha...
# 3017620422003  [{'material': 'en:clear-glass', 'number_of_uni...
# 7622210449283  [{'material': 'en:plastic', 'number_of_units':...
# 5449000214911  [{'material': 'en:aluminium', 'number_of_units...
# 3017620425035  [{'material': 'xx:82-c-pap', 'number_of_units'...
# ...                                                          ...
# 8690565330289  [{'material': 'en:plastic', 'number_of_units':...
# 4021234101109  [{'material': 'en:pp-5-polypropylene', 'number...
# 4104420141827  [{'material': 'en:paper-and-plastic', 'number_...
# 42372394       [{'material': 'en:aluminium', 'shape': 'en:can'}]
# 9002055108817  [{'material': 'en:aluminium', 'number_of_units...
#
#                                           product_name  unique_scans_n  \
# code
# 3274080005003                            Eau de source            1073
# 3017620422003                                  Nutella             923
# 7622210449283  Prince Chocolat biscuits au blé complet             842
# 5449000214911                                Coca-cola             685
# 3017620425035                                  Nutella             623
# ...                                                ...             ...
# 8690565330289    Ayran (Joghurtgetränk türkischer Art)               2
# 4021234101109             Krunchy Christmas Haferbasis               2
# 4104420141827                           Joghurt Butter               2
# 42372394                  Weissbier-Radler Grapefrucht               2
# 9002055108817                Salanettis (Salami-Snack)               2
#
#                pack_count                                      pack_shapes  \
# code
# 3274080005003           3             [en:bottle, en:bottle-cap, en:label]
# 3017620422003           5  [en:pot, en:lid, en:backing, en:seal, en:label]
# 7622210449283           2                             [en:film, en:sleeve]
# 5449000214911           1                                   [en:drink-can]
# 3017620425035           5  [en:seal, en:lid, en:jar, en:backing, en:label]
# ...                   ...                                              ...
# 8690565330289           2                                 [en:can, en:lid]
# 4021234101109           1                                         [en:bag]
# 4104420141827           1                                   [en:packaging]
# 42372394                1                                         [en:can]
# 9002055108817           1                                      [en:packet]
#
#                                                   pack_materials
# code
# 3274080005003  [en:pet-1-polyethylene-terephthalate, en:hdpe-...
# 3017620422003  [en:clear-glass, en:pp-5-polypropylene, en:non...
# 7622210449283                         [en:plastic, en:cardboard]
# 5449000214911                                     [en:aluminium]
# 3017620425035  [xx:82-c-pap, en:pp-5-polypropylene, en:clear-...
# ...                                                          ...
# 8690565330289                         [en:plastic, en:aluminium]
# 4021234101109                            [en:pp-5-polypropylene]
# 4104420141827                             [en:paper-and-plastic]
# 42372394                                          [en:aluminium]
# 9002055108817                                     [en:aluminium]
#
# [1000 rows x 8 columns]

# %% [markdown]
# ## Visualize the top scanned products

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import PIL.Image
from textwrap import wrap


def plot_prods(df: pd.DataFrame, cols: int = 6, max: int = 54, title: str = None):
    n = df.shape[0]
    if n > max:
        n = max

    rows = math.ceil(n/cols)
    height = 2 + 16/9 * rows

    fig, axs = plt.subplots(rows, cols, figsize=(10, height))
    
    trunc = lambda s, l: s[:l-2] + '..' if len(s) >= l else s
    
    for i, ax in enumerate(axs.flat):
    
        if i >= n:
            ax.set_axis_off()
            continue
        
        data = df.iloc[i]
        pack = [f"{s[3:] if s else s}: {trunc(m[3:], 20) if m else m}" for s, m in zip(data.pack_shapes, data.pack_materials)]
    
        name = "\n".join(wrap(data.product_name, 20)) if data.product_name else "<NO NAME>"
        name += f"\n({data.unique_scans_n} scans)"
        color = 'black' if data.product_name else 'red'
        fontweight = '500' if data.product_name else '600'
        
        ax.set_title(name, color=color, fontweight=fontweight, size=8)
        
            
        ax.set_xlabel("\n".join(pack), size=6)
    
        ax.set_frame_on(False)
        ax.set_xticks([])
        ax.set_yticks([])
    
        # show image if product has image url
        if type(data.image_small_url) == str:
            # load image
            with urlopen(data.image_small_url) as response:
                im = PIL.Image.open(response)
                im = np.array(im)
                ax.imshow(im)
        else:
            ax.text(0.5, 0.5, "<NO IMAGE>", horizontalalignment='center', color='red', fontweight='bold')
    
    fig.tight_layout()
    fig.subplots_adjust(top=0.93)
    fig.suptitle(title);
    
    plt.savefig("off_top_products_germany.png")

plot_prods(prod_df, title="Top Scanned Products with Complete Packaging (in Germany)")

# %% [markdown]
# ## Basic Statistics
#
# ### Frequency of products that have 1..n packaging items
#
# <div class="alert alert-block alert-danger">
#   <b>Some products have no packaging information - This should not be the case with status "packagings_complete".</b>
# </div>

# %%
prod_df.pack_count.value_counts().sort_index().plot.barh(figsize=(4,3));

# %% [markdown]
# ### Show items without packaging information

# %%
prod_df[lambda df: df.pack_count == 0]
# Out:
#                                               brands  \
# code
# 8710912064749                                 Valess
# 4061458007115      Knusperone, H. & J. Brüggen, Aldi
# 20793739                             Natur Gut Penny
# 4260188785588                               mymuesli
# 7622210678041                               Mondelez
# 4063367226069                              K-Classic
# 8600939212295                                  Stark
# 3250392949228                             Saint eloi
# 5059319007649  Kellogg's, Kellogg's - KELLOG Company
# 4015637827094                              Bauck Hof
# 5449000138514                              Coca-Cola
# 4008366010004                                 FROSTA
#
#                                                  image_small_url packagings  \
# code
# 8710912064749  https://images.openfoodfacts.org/images/produc...         []
# 4061458007115  https://images.openfoodfacts.org/images/produc...         []
# 20793739       https://images.openfoodfacts.org/images/produc...         []
# 4260188785588  https://images.openfoodfacts.org/images/produc...         []
# 7622210678041  https://images.openfoodfacts.org/images/produc...         []
# 4063367226069  https://images.openfoodfacts.org/images/produc...         []
# 8600939212295  https://images.openfoodfacts.org/images/produc...         []
# 3250392949228  https://images.openfoodfacts.org/images/produc...         []
# 5059319007649  https://images.openfoodfacts.org/images/produc...         []
# 4015637827094  https://images.openfoodfacts.org/images/produc...         []
# 5449000138514  https://images.openfoodfacts.org/images/produc...         []
# 4008366010004  https://images.openfoodfacts.org/images/produc...         []
#
#                                      product_name  unique_scans_n  pack_count  \
# code
# 8710912064749              Vegetarische Schnitzel              19           0
# 4061458007115     Premium-Müsli - Früchte & Nüsse              23           0
# 20793739                     Bio fettarme H-Milch               8           0
# 4260188785588                           Blueberry               6           0
# 7622210678041                            Daim XXL               5           0
# 4063367226069           Delikatess Feine Teewurst               5           0
# 8600939212295                       Prima peanuts               4           0
# 3250392949228                       Mais BIO 285g               4           0
# 5059319007649                     Miel pops loops               4           0
# 4015637827094  Wunder Brød mit Nüssen, glutenfrei               4           0
# 5449000138514                      Coca-Cola zero               3           0
# 4008366010004               Tortellini Rahmspinat               2           0
#
#               pack_shapes pack_materials
# code
# 8710912064749          []             []
# 4061458007115          []             []
# 20793739               []             []
# 4260188785588          []             []
# 7622210678041          []             []
# 4063367226069          []             []
# 8600939212295          []             []
# 3250392949228          []             []
# 5059319007649          []             []
# 4015637827094          []             []
# 5449000138514          []             []
# 4008366010004          []             []

# %% [markdown]
# ### Product without product name
#
# <div class="alert alert-block alert-danger">
#   <b>Some products have no product name - This is surprising when status is "packagings_complete".</b>
# </div>

# %%
missing_name = prod_df.product_name == ""
prod_df[missing_name]
# Out:
#                                                           brands  \
# code
# 80135463                                                 Ferrero
# 3046920029759                                              Lindt
# 54491472                                               Coca-Cola
# 3155251205500                                          President
# 7311070346916                                              Pagen
# 20575342                                                 Milbona
# 5413548280189                                     Kinder,Ferrero
# 4000607852008                                         Schogetten
# 4046434029305                                            Essreif
# 4056489110118  Envia,Lidl,Milbona, 1001 Delights (Lidl), Milb...
# 20021139                                            French Style
# 4000417028006                                       Ritter Sport
# 4250241204231                                               iglo
# 4063367230332                                          K-Classic
# 8000500256213                                     Kinder,Ferrero
# 4056489417675                                            Sondey,
# 4058172451553                                          dm, dmBio
# 4004790103305                                             Berief
# 4104060010965                                    Andechser Natur
# 7300400482677                                               Wasa
# 5902729241199                                           Gotszlik
# 7622210496669                                          Toblerone
#
#                                                  image_small_url  \
# code
# 80135463       https://images.openfoodfacts.org/images/produc...
# 3046920029759  https://images.openfoodfacts.org/images/produc...
# 54491472       https://images.openfoodfacts.org/images/produc...
# 3155251205500  https://images.openfoodfacts.org/images/produc...
# 7311070346916  https://images.openfoodfacts.org/images/produc...
# 20575342       https://images.openfoodfacts.org/images/produc...
# 5413548280189  https://images.openfoodfacts.org/images/produc...
# 4000607852008  https://images.openfoodfacts.org/images/produc...
# 4046434029305  https://images.openfoodfacts.org/images/produc...
# 4056489110118  https://images.openfoodfacts.org/images/produc...
# 20021139       https://images.openfoodfacts.org/images/produc...
# 4000417028006  https://images.openfoodfacts.org/images/produc...
# 4250241204231  https://images.openfoodfacts.org/images/produc...
# 4063367230332  https://images.openfoodfacts.org/images/produc...
# 8000500256213  https://images.openfoodfacts.org/images/produc...
# 4056489417675                                                NaN
# 4058172451553  https://images.openfoodfacts.org/images/produc...
# 4004790103305  https://images.openfoodfacts.org/images/produc...
# 4104060010965  https://images.openfoodfacts.org/images/produc...
# 7300400482677  https://images.openfoodfacts.org/images/produc...
# 5902729241199  https://images.openfoodfacts.org/images/produc...
# 7622210496669  https://images.openfoodfacts.org/images/produc...
#
#                                                       packagings product_name  \
# code
# 80135463       [{'material': 'en:ldpe-4-low-density-polyethyl...
# 3046920029759  [{'material': 'en:aluminium', 'number_of_units...
# 54491472       [{'material': 'en:pet-1-polyethylene-terephtha...
# 3155251205500  [{'material': 'en:plastic', 'number_of_units':...
# 7311070346916  [{'material': 'en:pp-5-polypropylene', 'number...
# 20575342       [{'material': 'en:plastic', 'number_of_units':...
# 5413548280189  [{'material': 'en:pp-5-polypropylene', 'number...
# 4000607852008  [{'material': 'en:cardboard', 'number_of_units...
# 4046434029305  [{'material': 'en:paper', 'number_of_units': 1...
# 4056489110118  [{'material': 'en:pp-5-polypropylene', 'number...
# 20021139       [{'material': 'en:plastic', 'number_of_units':...
# 4000417028006  [{'material': 'en:pp-5-polypropylene', 'number...
# 4250241204231  [{'material': 'en:paperboard', 'number_of_unit...
# 4063367230332            [{'material': 'en:pp-5-polypropylene'}]
# 8000500256213  [{'material': 'en:o-7-other-plastics', 'number...
# 4056489417675  [{'material': 'en:plastic', 'number_of_units':...
# 4058172451553  [{'material': 'en:paper-and-plastic', 'number_...
# 4004790103305  [{'material': 'en:paperboard', 'number_of_unit...
# 4104060010965  [{'material': 'en:glass-tinplate', 'recycling'...
# 7300400482677  [{'material': 'en:pp-5-polypropylene', 'number...
# 5902729241199  [{'material': 'en:plastic', 'number_of_units':...
# 7622210496669  [{'material': 'en:aluminium', 'number_of_units...
#
#                unique_scans_n  pack_count  \
# code
# 80135463                  372           4
# 3046920029759             311           2
# 54491472                  249           1
# 3155251205500             182           1
# 7311070346916              65           1
# 20575342                   28           2
# 5413548280189              27           2
# 4000607852008              24           3
# 4046434029305              28           1
# 4056489110118              23           2
# 20021139                   15           2
# 4000417028006              16           1
# 4250241204231              15           1
# 4063367230332              10           1
# 8000500256213               9           2
# 4056489417675               9           2
# 4058172451553               8           1
# 4004790103305               6           2
# 4104060010965              17           1
# 7300400482677               8           1
# 5902729241199               3           2
# 7622210496669               2           2
#
#                                        pack_shapes  \
# code
# 80135463       [en:lid, en:seal, en:pot, en:label]
# 3046920029759                [en:sheet, en:sleeve]
# 54491472                               [en:bottle]
# 3155251205500                           [en:sheet]
# 7311070346916                             [en:bag]
# 20575342                        [en:tray, en:seal]
# 5413548280189                [en:envelope, en:bag]
# 4000607852008       [en:sleeve, en:tray, en:sheet]
# 4046434029305                         [en:Sticker]
# 4056489110118                     [en:pot, en:lid]
# 20021139                        [en:film, en:tray]
# 4000417028006                        [it: Incarto]
# 4250241204231                             [en:box]
# 4063367230332                               [None]
# 8000500256213                 [en:bag, en:wrapper]
# 4056489417675                [en:sleeve, en:sheet]
# 4058172451553                            [en:film]
# 4004790103305                 [en:box, en:wrapper]
# 4104060010965                               [None]
# 7300400482677                             [en:bag]
# 5902729241199         [en:packaging, en:packaging]
# 7622210496669               [en:packaging, en:box]
#
#                                                   pack_materials
# code
# 80135463       [en:ldpe-4-low-density-polyethylene, xx:82-c-p...
# 3046920029759                       [en:aluminium, en:cardboard]
# 54491472                   [en:pet-1-polyethylene-terephthalate]
# 3155251205500                                       [en:plastic]
# 7311070346916                            [en:pp-5-polypropylene]
# 20575342                                [en:plastic, en:plastic]
# 5413548280189     [en:pp-5-polypropylene, en:pp-5-polypropylene]
# 4000607852008         [en:cardboard, en:cardboard, en:aluminium]
# 4046434029305                                         [en:paper]
# 4056489110118     [en:pp-5-polypropylene, en:pp-5-polypropylene]
# 20021139                                [en:plastic, en:plastic]
# 4000417028006                            [en:pp-5-polypropylene]
# 4250241204231                                    [en:paperboard]
# 4063367230332                            [en:pp-5-polypropylene]
# 8000500256213     [en:o-7-other-plastics, en:pp-5-polypropylene]
# 4056489417675                             [en:plastic, en:paper]
# 4058172451553                             [en:paper-and-plastic]
# 4004790103305                        [en:paperboard, en:plastic]
# 4104060010965                                [en:glass-tinplate]
# 7300400482677                            [en:pp-5-polypropylene]
# 5902729241199                         [en:plastic, en:cardboard]
# 7622210496669                       [en:aluminium, en:cardboard]

# %% [markdown]
# ### Items with incomplete "shape" data
#
# <div class="alert alert-block alert-danger">
#   <b>Some products are missing packaging "shape" data. This should not be the case with status "packagings_complete".</b>
# </div>

# %%
is_missing = lambda x: len(x) == 0 or None in x

missing_shapes = prod_df.pack_shapes.map(is_missing)
missing_shapes.map(lambda x: 'missing shape' if x else 'has shape').value_counts()
# Out:
# pack_shapes
# has shape        937
# missing shape     63
# Name: count, dtype: int64

# %%
prod_df[missing_shapes]
# Out:
#                                          brands  \
# code
# 4008400401829                           Ferrero
# 5010029201246                             Alpen
# 4011100001305                              Mars
# 20006105                                Tastino
# 4056489232872                           Belbake
# ...                                         ...
# 4260462119887      Cay-Consulting GmbH & Co. KG
# 4008366010004                            FROSTA
# 4316268588843                            BioBio
# 4061458012911  Gut Bio, Willms Weißwasser, Aldi
# 4061458010917                           Choceur
#
#                                                  image_small_url  \
# code
# 4008400401829  https://images.openfoodfacts.org/images/produc...
# 5010029201246  https://images.openfoodfacts.org/images/produc...
# 4011100001305  https://images.openfoodfacts.org/images/produc...
# 20006105       https://images.openfoodfacts.org/images/produc...
# 4056489232872  https://images.openfoodfacts.org/images/produc...
# ...                                                          ...
# 4260462119887  https://images.openfoodfacts.org/images/produc...
# 4008366010004  https://images.openfoodfacts.org/images/produc...
# 4316268588843  https://images.openfoodfacts.org/images/produc...
# 4061458012911  https://images.openfoodfacts.org/images/produc...
# 4061458010917  https://images.openfoodfacts.org/images/produc...
#
#                                                       packagings  \
# code
# 4008400401829  [{'material': 'xx:82-c-pap'}, {'material': 'en...
# 5010029201246  [{'material': 'en:plastic'}, {'material': 'en:...
# 4011100001305                       [{'material': 'en:plastic'}]
# 20006105       [{'material': 'en:pp-5-polypropylene'}, {'mate...
# 4056489232872                      [{'recycling': 'en:recycle'}]
# ...                                                          ...
# 4260462119887  [{'material': 'en:glass-aluminium', 'number_of...
# 4008366010004                                                 []
# 4316268588843                       [{'material': 'en:plastic'}]
# 4061458012911            [{'material': 'de:Kunststoff, Papier'}]
# 4061458010917  [{'material': 'en:pp-5-polypropylene', 'number...
#
#                                           product_name  unique_scans_n  \
# code
# 4008400401829                                  Nutella             126
# 5010029201246  Müsli No Added Sugar Swiss Style Muesli              76
# 4011100001305                                    M&M's              48
# 20006105                       Pan de centeno integral              33
# 4056489232872                             Cocoa powder              32
# ...                                                ...             ...
# 4260462119887            Cay Gourmet Crunchy Haselnuss               3
# 4008366010004                    Tortellini Rahmspinat               2
# 4316268588843                         Krusten Brötchen               2
# 4061458012911                Bio-Hähnchen-Fleischwurst               2
# 4061458010917                         Kokos Schokolade               2
#
#                pack_count                            pack_shapes  \
# code
# 4008400401829           5  [None, en:lid, en:seal, en:pot, None]
# 5010029201246           3                 [None, en:box, en:bag]
# 4011100001305           1                                 [None]
# 20006105                2                    [None, en:fastener]
# 4056489232872           1                                 [None]
# ...                   ...                                    ...
# 4260462119887           2                       [None, en:label]
# 4008366010004           0                                     []
# 4316268588843           1                                 [None]
# 4061458012911           1                                 [None]
# 4061458010917           1                                 [None]
#
#                                                   pack_materials
# code
# 4008400401829  [xx:82-c-pap, en:pp-5-polypropylene, en:alumin...
# 5010029201246             [en:plastic, en:cardboard, en:plastic]
# 4011100001305                                       [en:plastic]
# 20006105                     [en:pp-5-polypropylene, en:plastic]
# 4056489232872                                             [None]
# ...                                                          ...
# 4260462119887                   [en:glass-aluminium, en:plastic]
# 4008366010004                                                 []
# 4316268588843                                       [en:plastic]
# 4061458012911                            [de:Kunststoff, Papier]
# 4061458010917                            [en:pp-5-polypropylene]
#
# [63 rows x 8 columns]

# %% [markdown]
# ### Items with incomplete "materials" data
#
# <div class="alert alert-block alert-danger">
#   <b>Some products are missing packaging "material" data. This should not be the case with status "packagings_complete".</b>
# </div>

# %%
missing_materials = prod_df.pack_materials.map(is_missing)
missing_materials.map(lambda x: 'missing material' if x else 'has material').value_counts()
# Out:
# pack_materials
# has material        931
# missing material     69
# Name: count, dtype: int64

# %%
prod_df[missing_materials]
# Out:
#                               brands  \
# code
# 3274080005003             Cristaline
# 8000500310427        Nutella,Ferrero
# 3017620429484        Ferrero,Nutella
# 20267605       Alesto Selection,Lidl
# 7613035040823  Nestlé,Nestlé Dessert
# ...                              ...
# 4006040422013               Rapunzel
# 4311501648926                  Edeka
# 5449000138514              Coca-Cola
# 20250393                 Lidl, Helma
# 4008366010004                 FROSTA
#
#                                                  image_small_url  \
# code
# 3274080005003  https://images.openfoodfacts.org/images/produc...
# 8000500310427  https://images.openfoodfacts.org/images/produc...
# 3017620429484  https://images.openfoodfacts.org/images/produc...
# 20267605       https://images.openfoodfacts.org/images/produc...
# 7613035040823  https://images.openfoodfacts.org/images/produc...
# ...                                                          ...
# 4006040422013  https://images.openfoodfacts.org/images/produc...
# 4311501648926  https://images.openfoodfacts.org/images/produc...
# 5449000138514  https://images.openfoodfacts.org/images/produc...
# 20250393       https://images.openfoodfacts.org/images/produc...
# 4008366010004  https://images.openfoodfacts.org/images/produc...
#
#                                                       packagings  \
# code
# 3274080005003  [{'material': 'en:pet-1-polyethylene-terephtha...
# 8000500310427  [{'material': 'en:o-7-other-plastics', 'number...
# 3017620429484  [{'material': 'en:clear-glass', 'number_of_uni...
# 20267605       [{'number_of_units': 1, 'quantity_per_unit': '...
# 7613035040823  [{'material': 'en:aluminium', 'number_of_units...
# ...                                                          ...
# 4006040422013  [{'material': 'en:non-corrugated-cardboard', '...
# 4311501648926  [{'material': 'en:plastic', 'number_of_units':...
# 5449000138514                                                 []
# 20250393       [{'material': 'en:plastic', 'number_of_units':...
# 4008366010004                                                 []
#
#                                                     product_name  \
# code
# 3274080005003                                      Eau de source
# 8000500310427  Ferrero- Nutella Biscuits Resealable Bag, 304g...
# 3017620429484                                            Nutella
# 20267605                                                Anacardi
# 7613035040823                                     Nestlé Dessert
# ...                                                          ...
# 4006040422013                 Rice Choco vegane helle Schokolade
# 4311501648926                                  12 Milch BRÖTCHEN
# 5449000138514                                     Coca-Cola zero
# 20250393                        Speisefrühkartoffeln festkochend
# 4008366010004                              Tortellini Rahmspinat
#
#                unique_scans_n  pack_count  \
# code
# 3274080005003            1073           3
# 8000500310427             429           2
# 3017620429484             343           6
# 20267605                  301           1
# 7613035040823             269           5
# ...                       ...         ...
# 4006040422013               1           2
# 4311501648926               2           2
# 5449000138514               3           0
# 20250393                    3           2
# 4008366010004               2           0
#
#                                                      pack_shapes  \
# code
# 3274080005003               [en:bottle, en:bottle-cap, en:label]
# 8000500310427                              [en:bag, en:envelope]
# 3017620429484  [en:pot, en:seal, en:lid, en:label, en:backing...
# 20267605                                                [en:bag]
# 7613035040823     [en:sheet, en:sheet, en:film, en:tray, en:box]
# ...                                                          ...
# 4006040422013                                [en:brick, en:film]
# 4311501648926                              [en:bag, en:fastener]
# 5449000138514                                                 []
# 20250393                                      [en:net, en:label]
# 4008366010004                                                 []
#
#                                                   pack_materials
# code
# 3274080005003  [en:pet-1-polyethylene-terephthalate, en:hdpe-...
# 8000500310427                      [en:o-7-other-plastics, None]
# 3017620429484  [en:clear-glass, xx:82-c-pap, en:pp-5-polyprop...
# 20267605                                                  [None]
# 7613035040823   [en:aluminium, en:paper, en:plastic, None, None]
# ...                                                          ...
# 4006040422013                [en:non-corrugated-cardboard, None]
# 4311501648926                                 [en:plastic, None]
# 5449000138514                                                 []
# 20250393                                      [en:plastic, None]
# 4008366010004                                                 []
#
# [69 rows x 8 columns]

# %% [markdown]
# ## Labels of Packaging Shapes

# %%
packagingShapes = [s for shapes in prod_df.pack_shapes for s in shapes]
packagingShapesEn = [s for s in packagingShapes if s and s.startswith('en:')]
packagingShapesNonEn = [s for s in packagingShapes if s and not s.startswith('en:')]

# %% [markdown]
# ### Most Frequent English Shape Labels

# %%
pd.Series(packagingShapesEn).value_counts(ascending=True).plot.barh(figsize=(6, 9));

# %% [markdown]
# ### Most Frequent Non-English Shape Labels
#
# <div class="alert alert-block alert-danger">
#   <b>All products should use the standard english taxonomy names if status is "packagings_complete".</b>
# </div>

# %%
pd.Series(packagingShapesNonEn).value_counts(ascending=True).plot.barh(figsize=(4, 5));

# %% [markdown]
# ### Investigate products with specific package shape labels
#
# - pizza-box
# - brick
# - Siegelfolie (German)

# %%
search = 'en:pizza-box'
prod_df[lambda df: df.pack_shapes.map(lambda shapes: search in shapes)]
# Out:
#                                            brands  \
# code
# 4001724039297               Dr. Oetker Ristorante
# 4009233014002  Wagner,Original Wagner,Fertigessen
# 4250073457669                          Followfood
#
#                                                  image_small_url  \
# code
# 4001724039297  https://images.openfoodfacts.org/images/produc...
# 4009233014002  https://images.openfoodfacts.org/images/produc...
# 4250073457669  https://images.openfoodfacts.org/images/produc...
#
#                                                       packagings  \
# code
# 4001724039297  [{'material': 'en:cardboard', 'number_of_units...
# 4009233014002  [{'material': 'en:non-corrugated-cardboard', '...
# 4250073457669  [{'material': 'en:plastic', 'number_of_units':...
#
#                                    product_name  unique_scans_n  pack_count  \
# code
# 4001724039297     Pizza Salame Mozzarella Pesto               7           2
# 4009233014002                 Piccolinis Salami               8           1
# 4250073457669  Pizza Funghi mit Bio Dinkelboden               4           2
#
#                               pack_shapes                 pack_materials
# code
# 4001724039297      [en:pizza-box, en:bag]     [en:cardboard, en:plastic]
# 4009233014002              [en:pizza-box]  [en:non-corrugated-cardboard]
# 4250073457669  [en:wrapper, en:pizza-box]         [en:plastic, en:paper]

# %%
search = 'en:brick'
prod_df[lambda df: df.pack_shapes.map(lambda shapes: search in shapes)]
# Out:
#                                                   brands  \
# code
# 8076800195057                                    Barilla
# 4056489346357                              Vemondo, Lidl
# 5411188115472                                      Alpro
# 4056489244691               Vemondo, Lidl, Grønvang Food
# 40264769       Deli Reform, Walter Rau Lebensmittelwerke
# ...                                                  ...
# 4006040422013                                   Rapunzel
# 5411188511328                                      Alpro
# 7610200391186                           Valflora, Migros
# 4063608500033                                     Velike
# 5411188135579                                      Alpro
#
#                                                  image_small_url  \
# code
# 8076800195057  https://images.openfoodfacts.org/images/produc...
# 4056489346357  https://images.openfoodfacts.org/images/produc...
# 5411188115472  https://images.openfoodfacts.org/images/produc...
# 4056489244691  https://images.openfoodfacts.org/images/produc...
# 40264769       https://images.openfoodfacts.org/images/produc...
# ...                                                          ...
# 4006040422013  https://images.openfoodfacts.org/images/produc...
# 5411188511328  https://images.openfoodfacts.org/images/produc...
# 7610200391186  https://images.openfoodfacts.org/images/produc...
# 4063608500033  https://images.openfoodfacts.org/images/produc...
# 5411188135579  https://images.openfoodfacts.org/images/produc...
#
#                                                       packagings  \
# code
# 8076800195057  [{'material': 'en:non-corrugated-cardboard', '...
# 4056489346357  [{'material': 'en:cardboard', 'number_of_units...
# 5411188115472  [{'material': 'en:plastic', 'shape': 'en:bottl...
# 4056489244691  [{'material': 'en:hdpe-2-high-density-polyethy...
# 40264769       [{'material': 'en:pp-5-polypropylene', 'number...
# ...                                                          ...
# 4006040422013  [{'material': 'en:non-corrugated-cardboard', '...
# 5411188511328  [{'material': 'en:tetra-pak', 'number_of_units...
# 7610200391186  [{'material': 'en:tetra-pak', 'number_of_units...
# 4063608500033  [{'material': 'en:paperboard', 'number_of_unit...
# 5411188135579  [{'material': 'en:tetra-brik-aseptic', 'number...
#
#                                      product_name  unique_scans_n  pack_count  \
# code
# 8076800195057                       Spaghetti n.5             255           1
# 4056489346357                   Bio lait d'amande             156           2
# 5411188115472             Soja riche en protéines             150           2
# 4056489244691         Bio Hafer ohne Zuckerzusatz             126           3
# 40264769               Deli Reform - Das Original             101           4
# ...                                           ...             ...         ...
# 4006040422013  Rice Choco vegane helle Schokolade               1           2
# 5411188511328                   Single Soya cream               1           2
# 7610200391186                          Demi-crème               1           1
# 4063608500033          Bio Hafer Drink mit Mandel               4           2
# 5411188135579              Alpro this is not milk               4           2
#
#                                                 pack_shapes  \
# code
# 8076800195057                                    [en:brick]
# 4056489346357                     [en:brick, en:bottle-cap]
# 5411188115472                     [en:bottle-cap, en:brick]
# 4056489244691            [en:lid, en:brick, de:Siegelfolie]
# 40264769       [en:lid, en:label, en:brick, de:Siegelfolie]
# ...                                                     ...
# 4006040422013                           [en:brick, en:film]
# 5411188511328                     [en:brick, en:lid-or-cap]
# 7610200391186                                    [en:brick]
# 4063608500033                            [en:brick, en:lid]
# 5411188135579                            [en:brick, en:lid]
#
#                                                   pack_materials
# code
# 8076800195057                      [en:non-corrugated-cardboard]
# 4056489346357                         [en:cardboard, en:plastic]
# 5411188115472                         [en:plastic, en:tetra-pak]
# 4056489244691  [en:hdpe-2-high-density-polyethylene, xx:84-c-...
# 40264769       [en:pp-5-polypropylene, en:paper, en:pp-5-poly...
# ...                                                          ...
# 4006040422013                [en:non-corrugated-cardboard, None]
# 5411188511328                         [en:tetra-pak, en:plastic]
# 7610200391186                                     [en:tetra-pak]
# 4063608500033                        [en:paperboard, en:plastic]
# 5411188135579                [en:tetra-brik-aseptic, en:plastic]
#
# [65 rows x 8 columns]

# %%
search = 'de:Siegelfolie'
prod_df[lambda df: df.pack_shapes.map(lambda shapes: search in shapes)]
# Out:
#                                                   brands  \
# code
# 4056489244691               Vemondo, Lidl, Grønvang Food
# 40264769       Deli Reform, Walter Rau Lebensmittelwerke
# 20810405            Chef select, Lidl, Heinrich Kühlmann
# 20521493                                         Vitasia
# 8715700209159                                      Heinz
# 4061458135115        Wonnemeyer, ALDI, Heinrich Kühlmann
# 8719200237025                Lätta,Upfield, Lätta, Lätta
# 8690804682902                      Suntat, BLG Kardesler
# 4002674044959                                    Ostmann
#
#                                                  image_small_url  \
# code
# 4056489244691  https://images.openfoodfacts.org/images/produc...
# 40264769       https://images.openfoodfacts.org/images/produc...
# 20810405       https://images.openfoodfacts.org/images/produc...
# 20521493       https://images.openfoodfacts.org/images/produc...
# 8715700209159  https://images.openfoodfacts.org/images/produc...
# 4061458135115  https://images.openfoodfacts.org/images/produc...
# 8719200237025  https://images.openfoodfacts.org/images/produc...
# 8690804682902  https://images.openfoodfacts.org/images/produc...
# 4002674044959  https://images.openfoodfacts.org/images/produc...
#
#                                                       packagings  \
# code
# 4056489244691  [{'material': 'en:hdpe-2-high-density-polyethy...
# 40264769       [{'material': 'en:pp-5-polypropylene', 'number...
# 20810405       [{'material': 'en:pet-1-polyethylene-terephtha...
# 20521493       [{'material': 'en:clear-glass', 'number_of_uni...
# 8715700209159  [{'material': 'en:pet-transparent', 'number_of...
# 4061458135115  [{'material': 'en:pet-transparent', 'number_of...
# 8719200237025  [{'material': 'en:plastic', 'number_of_units':...
# 8690804682902  [{'material': 'en:clear-glass', 'number_of_uni...
# 4002674044959  [{'material': 'en:pp-5-polypropylene', 'number...
#
#                                      product_name  unique_scans_n  pack_count  \
# code
# 4056489244691         Bio Hafer ohne Zuckerzusatz             126           3
# 40264769               Deli Reform - Das Original             101           4
# 20810405       Hummus Pikant mit Chili verfeinert              39           3
# 20521493                                Soja Soße              36           6
# 8715700209159             Mayonnaise Das Original              26           4
# 4061458135115              Hummus - Ras El Hanout              25           4
# 8719200237025                               Lätta              18           3
# 8690804682902                    Tahin Sesampaste               9           4
# 4002674044959                   Rosmarin gemahlen               3           4
#
#                                                      pack_shapes  \
# code
# 4056489244691                 [en:lid, en:brick, de:Siegelfolie]
# 40264769            [en:lid, en:label, en:brick, de:Siegelfolie]
# 20810405                       [en:tray, en:lid, de:Siegelfolie]
# 20521493       [en:bottle, en:lid, de:Siegelfolie, en:label, ...
# 8715700209159      [en:bottle, en:lid, de:Siegelfolie, en:label]
# 4061458135115        [en:tray, en:lid, de:Siegelfolie, en:label]
# 8719200237025                  [en:tray, en:lid, de:Siegelfolie]
# 8690804682902         [en:jar, en:lid, de:Siegelfolie, en:label]
# 4002674044959         [en:can, en:lid, en:label, de:Siegelfolie]
#
#                                                   pack_materials
# code
# 4056489244691  [en:hdpe-2-high-density-polyethylene, xx:84-c-...
# 40264769       [en:pp-5-polypropylene, en:paper, en:pp-5-poly...
# 20810405       [en:pet-1-polyethylene-terephthalate, en:pet-1...
# 20521493       [en:clear-glass, en:pp-5-polypropylene, en:pla...
# 8715700209159  [en:pet-transparent, en:pp-5-polypropylene, No...
# 4061458135115  [en:pet-transparent, en:pet-transparent, en:pl...
# 8719200237025             [en:plastic, en:plastic, en:aluminium]
# 8690804682902  [en:clear-glass, en:plastic-tinplate, en:plast...
# 4002674044959  [en:pp-5-polypropylene, en:plastic, en:plastic...

# %% [markdown]
# ### Product packagings example

# %%
prod_df.iloc[59].packagings
# Out:
# [{'material': 'fr:Carton + plastique PE',
#   'number_of_units': 1,
#   'quantity_per_unit': '406 g',
#   'quantity_per_unit_unit': 'g',
#   'quantity_per_unit_value': '406',
#   'recycling': 'en:recycle',
#   'shape': 'en:pot',
#   'weight_measured': 14.85},
#  {'material': 'fr:Carton + plastique Pe',
#   'number_of_units': 1,
#   'quantity_per_unit': '406 g',
#   'quantity_per_unit_unit': 'g',
#   'quantity_per_unit_value': '406',
#   'recycling': 'en:recycle',
#   'shape': 'en:lid',
#   'weight_measured': 6.65},
#  {'material': 'fr:Plastique pp',
#   'number_of_units': '1',
#   'quantity_per_unit': '406 g',
#   'quantity_per_unit_unit': 'g',
#   'quantity_per_unit_value': '406',
#   'recycling': 'en:recycle',
#   'shape': 'en:film'}]

# %% [markdown]
# ## Visualize Specific Packagings

# %%
bags_df = prod_df[lambda df: df.pack_shapes.map(lambda arr: "en:bag" in arr)]
plot_prods(bags_df, max=18, title="Bag Packaging")

# %%
brick_df = prod_df[lambda df: df.pack_shapes.map(lambda arr: "en:brick" in arr)]
plot_prods(brick_df, max=18, title="Brick Packaging")

# %%
# lid, jar, _tray_, pot, box, package
# Nutella jar/pot
# yogurt pot?

packet_df = prod_df[lambda df: df.pack_shapes.map(lambda arr: "en:packet" in arr)]
plot_prods(packet_df, max=18, title="Packet Packaging")

# %% [markdown]
# ## Labels of Packaging Material

# %%
packagingMaterials = [s for mat in prod_df.pack_materials for s in mat]
packagingMaterialsEn = [s for s in packagingMaterials if s and s.startswith('en:')]
packagingMaterialsNonEn = [s for s in packagingMaterials if s and not s.startswith('en:')]

# %% [markdown]
# ### Most Frequent English Material Labels

# %%
pd.Series(packagingMaterialsEn).value_counts(ascending=True).plot.barh(figsize=(6, 9));

# %% [markdown]
# ### Most Frequent Non-English Material Labels

# %%
pd.Series(packagingMaterialsNonEn).value_counts(ascending=True).plot.barh(figsize=(6, 9));
